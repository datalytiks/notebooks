# %% [markdown]
# ## Installiing Prophet and other libraries

# %%
print("version 1")

# %%
# !pip install pystan==3.3.0

# %%
# !pip install prophet

# %%
import prophet

# %% [markdown]
# ### Import core libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('https://datahub.io/core/co2-ppm-daily/r/co2-ppm-daily.csv')

# %%
df.info()

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()

# %%
df.columns = ['ds', 'y']

# %%
df.head()
# Out:
#           ds       y
# 0 1958-03-30  316.16
# 1 1958-03-31  316.40
# 2 1958-04-02  317.67
# 3 1958-04-03  317.76
# 4 1958-04-04  317.09

# %%
model = prophet.Prophet()
model.fit(df)

# %%
future = model.make_future_dataframe(periods=365 * 10)
forecast = model.predict(future)

# %%
fig = model.plot(forecast, xlabel='Date', ylabel=r'CO$_2$ PPM')
plt.title('Daily Carbon Dioxide Levels Measured at Mauna Loa')
plt.show()

# %% [markdown]
# ### Initial setup Gdrive, Kaggle

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !cp '/content/gdrive/My Drive/Colab Notebooks/Prophet/kaggle.json' .
os.environ['KAGGLE_CONFIG_DIR'] = '.'

# %% [markdown]
# ### Kaggle dataset download

# %%
# Download Kaggle Dataset !kaggle datasets download <user-name/dataset-name>
# !kaggle datasets download bhanupratapbiswas/inventory-analysis-case-study

# %%
# !unzip inventory-analysis-case-study.zip -d ./data/

# %%
# Download a Kaggle Competition dataset
# !kaggle competitions download -c quora-insincere-questions-classification -f train.csv -p data
# !kaggle competitions download -c quora-insincere-questions-classification -f test.csv -p data
# !kaggle competitions download -c quora-insincere-questions-classification -f sample_submission.csv -p data
